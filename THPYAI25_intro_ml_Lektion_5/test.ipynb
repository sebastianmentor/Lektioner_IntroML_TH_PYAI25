# %% [markdown]
# # Saga om data och liknande
#
# I den här notebook:en ska vi ta oss igenom en resa och utforska data och annat!
#
# 1. Vi använder markdown för att förmedla information
# 2. Vi kodar i så kallade kod-celler som går att köras individuellt från all annan kod (behändigt)
# 3. Oftast finns det ett syfte med notebooken men kan också användas för att experimentera!

# %%
# Testar vi lite kod 
5 + 5
var = "hejsan"
for c in var:
    print(chr(ord(c) + 2))
# Out:
# j
# g
# l
# u
# c
# p

# %%
import math
import datetime
print(math.sqrt(81))
print(math.sqrt(200))
# Out:
# 9.0
# 14.142135623730951

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 3, 17, 10, 49, 55, 431379)
